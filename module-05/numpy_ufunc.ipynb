# %%
a = [1, 2, 3]
b = [4, 5, 6]
z = []
for i,j in zip(a,b):
    z.append(i+j)

print(z)
# Out:
# [5, 7, 9]

# %%
import numpy as np
a = [1, 2, 3]
b = [4, 5, 6]
z = np.add(a,b)
print(z)
# Out:
# [5 7 9]

# %%
import numpy as np
a = [1, 2, 3]
b = [4, 5, 6]
c = [34, 45, 56]
d = [67, 78, 89]
def my_add(x,y):
    return x+y
new_add = np.frompyfunc(my_add,2,1)
z = new_add(a,b)
print(z)
try_add1 = my_add(5,6)
print(try_add)
def my_concat(x,y):
    return str(x)+str(y)
new_concat = np.frompyfunc(my_concat,2,1)
x = new_concat(c,d)
print(x)
# Out:
# [5 7 9]
# 11
# ['3467' '4578' '5689']
