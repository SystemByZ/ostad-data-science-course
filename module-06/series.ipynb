# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_list = [10, 20, 30]
names = ['Zihad', 'Rifat', 'Sakib']
salary = {
    '1': 50000,
    '2': 60000,
    '3': 70000
}
arr = np.array([40, 50, 60])

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(salary)
# Out:
# 1    50000
# 2    60000
# 3    70000
# dtype: int64

# %%
pd.Series(data = arr, index = labels)
# Out:
# a    40
# b    50
# c    60
# dtype: int64
